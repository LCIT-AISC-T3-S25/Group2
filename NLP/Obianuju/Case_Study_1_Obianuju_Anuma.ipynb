# %% [markdown]
# ### Question B-3. Compare the change in word frequencies from stemming and lemmatization.
# #### Which are the top 10 words after stemming/lemmatization?

# %%
import sys
import pandas as pd
import re
import nltk
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from collections import Counter
from nltk.corpus import stopwords

# %%
# Import the dataset
# sys.path.append('/Users/obianujuanuma/Library/CloudStorage/OneDrive-Personal/Loyalist/Semester 3/Natural Language Processing AISC2009')

corpus = pd.read_csv('Data.csv')

# %%
corpus.head()
# Out:
#                                                 Data
# 0  Watch or listen live weekdays at 8:30am MT at ...
# 1  Watch or listen live weekdays at 8:30am MT at ...
# 2               Chubby And Hot, Always Stir The Pot!
# 3               Chubby And Hot, Always Stir The Pot!
# 4  Journalist, publisher of Rebel News — telling ...

# %%
len(corpus)
# Out:
# 7339

# %%
# Create a Porter Stemmer Instance
porter_stemmer = PorterStemmer()

# Get all words from the data
words = corpus.iloc[:,0].astype(str).str.cat(sep= ' ') #Concatenate all rows into one string
pattern = r"\b[a-zA-Z][a-zA-Z'-]*[a-zA-Z]\b" #match words including hyphens and apostrophe
# print(words)

print()
# Clean the words
tokens = re.findall(pattern, words.lower())
print(f' Tokenized words: {tokens}\n')

# Apply stemming to each token
stemmed_words = [porter_stemmer.stem(token) for token in tokens]
print(f'Stemmed words: {stemmed_words}')
# Out:
#  Tokenized words: ['watch', 'or', 'listen', 'live', 'weekdays', 'at', 'mt', 'at', 'ryanjespersen', 'com', 'subscribe', 'via', 'youtube', 'or', 'your', 'favourite', 'podcast', 'app', 'realtalkrj', 'watch', 'or', 'listen', 'live', 'weekdays', 'at', 'mt', 'at', 'ryanjespersen', 'com', 'subscribe', 'via', 'youtube', 'or', 'your', 'favourite', 'podcast', 'app', 'realtalkrj', 'chubby', 'and', 'hot', 'always', 'stir', 'the', 'pot', 'chubby', 'and', 'hot', 'always', 'stir', 'the', 'pot', 'journalist', 'publisher', 'of', 'rebel', 'news', 'telling', 'the', 'other', 'side', 'of', 'the', 'story', 'awarded', 'the', 'queen', 'diamond', 'jubilee', 'medal', 'for', 'advancing', 'freedom', 'of', 'expression', 'edmonton', 'city', 'councillor', 'for', 'yeg', 'urban', 'planner', 'sustainability', 'sociologist', 'founder', 'cities', 'climate', 'action', 'health', 'inclusion', 'she', 'her', 'yegcc', 'albertan', 'mom', 'to', 'children', 'dogs', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', 'albertan', 'mom', 'to', 'children', 'dogs', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', 'albertan', 'mom', 'to', 'children', 'dogs', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', 'albertan', 'mom', 'to', 'children', 'dogs', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', 'former', 'progressive', 'conservative', 'specializing', 'in', 'delivering', 'satirical', 'irony', 'through', 'interpretive', 'dance', 'since', 'june', 'if', 'anyone', 'orders', 'merlot', "i'm", 'leaving', 'former', 'progressive', 'conservative', 'specializing', 'in', 'delivering', 'satirical', 'irony', 'through', 'interpretive', 'dance', 'since', 'june', 'if', 'anyone', 'orders', 'merlot', "i'm", 'leaving', "i'm", 'kuno', "gov't", 'qualified', 'service', 'dog', 'in', 'alberta', 'canada', 'my', 'job', 'is', 'taking', 'care', 'of', 'my', 'person', 'bilateral', 'amputee', 'weatherdog', 'spokesdog', 'for', 'the', 'disabled', "i'm", 'kuno', "gov't", 'qualified', 'service', 'dog', 'in', 'alberta', 'canada', 'my', 'job', 'is', 'taking', 'care', 'of', 'my', 'person', 'bilateral', 'amputee', 'weatherdog', 'spokesdog', 'for', 'the', 'disabled', 'albertan', 'mom', 'to', 'children', 'dogs', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', 'albertan', 'mom', 'to', 'children', 'dogs', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', 'albertan', 'mom', 'to', 'children', 'dogs', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', 'albertan', 'mom', 'to', 'children', 'dogs', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', 'albertan', 'mom', 'to', 'children', 'dogs', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', 'albertan', 'mom', 'to', 'children', 'dogs', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', "i'm", 'kuno', "gov't", 'qualified', 'service', 'dog', 'in', 'alberta', 'canada', 'my', 'job', 'is', 'taking', 'care', 'of', 'my', 'person', 'bilateral', 'amputee', 'weatherdog', 'spokesdog', 'for', 'the', 'disabled', 'think-tank', 'president', 'out-of-touch', 'opinion', 'elite', 'proud', 'husband', 'of', 'teacher', 'albertan', 'lgbtqally', 'he', 'him', 'mastodon', 'seandunn', 'hachyderm', ...
# Stemmed words: ['watch', 'or', 'listen', 'live', 'weekday', 'at', 'mt', 'at', 'ryanjespersen', 'com', 'subscrib', 'via', 'youtub', 'or', 'your', 'favourit', 'podcast', 'app', 'realtalkrj', 'watch', 'or', 'listen', 'live', 'weekday', 'at', 'mt', 'at', 'ryanjespersen', 'com', 'subscrib', 'via', 'youtub', 'or', 'your', 'favourit', 'podcast', 'app', 'realtalkrj', 'chubbi', 'and', 'hot', 'alway', 'stir', 'the', 'pot', 'chubbi', 'and', 'hot', 'alway', 'stir', 'the', 'pot', 'journalist', 'publish', 'of', 'rebel', 'news', 'tell', 'the', 'other', 'side', 'of', 'the', 'stori', 'award', 'the', 'queen', 'diamond', 'jubile', 'medal', 'for', 'advanc', 'freedom', 'of', 'express', 'edmonton', 'citi', 'councillor', 'for', 'yeg', 'urban', 'planner', 'sustain', 'sociologist', 'founder', 'citi', 'climat', 'action', 'health', 'inclus', 'she', 'her', 'yegcc', 'albertan', 'mom', 'to', 'children', 'dog', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', 'albertan', 'mom', 'to', 'children', 'dog', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', 'albertan', 'mom', 'to', 'children', 'dog', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', 'albertan', 'mom', 'to', 'children', 'dog', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', 'former', 'progress', 'conserv', 'special', 'in', 'deliv', 'satir', 'ironi', 'through', 'interpret', 'danc', 'sinc', 'june', 'if', 'anyon', 'order', 'merlot', "i'm", 'leav', 'former', 'progress', 'conserv', 'special', 'in', 'deliv', 'satir', 'ironi', 'through', 'interpret', 'danc', 'sinc', 'june', 'if', 'anyon', 'order', 'merlot', "i'm", 'leav', "i'm", 'kuno', "gov't", 'qualifi', 'servic', 'dog', 'in', 'alberta', 'canada', 'my', 'job', 'is', 'take', 'care', 'of', 'my', 'person', 'bilater', 'ampute', 'weatherdog', 'spokesdog', 'for', 'the', 'disabl', "i'm", 'kuno', "gov't", 'qualifi', 'servic', 'dog', 'in', 'alberta', 'canada', 'my', 'job', 'is', 'take', 'care', 'of', 'my', 'person', 'bilater', 'ampute', 'weatherdog', 'spokesdog', 'for', 'the', 'disabl', 'albertan', 'mom', 'to', 'children', 'dog', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', 'albertan', 'mom', 'to', 'children', 'dog', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', 'albertan', 'mom', 'to', 'children', 'dog', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', 'albertan', 'mom', 'to', 'children', 'dog', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', 'albertan', 'mom', 'to', 'children', 'dog', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', 'albertan', 'mom', 'to', 'children', 'dog', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', "i'm", 'kuno', "gov't", 'qualifi', 'servic', 'dog', 'in', 'alberta', 'canada', 'my', 'job', 'is', 'take', 'care', 'of', 'my', 'person', 'bilater', 'ampute', 'weatherdog', 'spokesdog', 'for', 'the', 'disabl', 'think-tank', 'presid', 'out-of-touch', 'opinion', 'elit', 'proud', 'husband', 'of', 'teacher', 'albertan', 'lgbtqalli', 'he', 'him', 'mastodon', 'seandunn', 'hachyderm', 'io', 'think-tank', 'presid', 'out-of-touch', 'opinion', 'elit', 'proud', 'husband', 'of', 'teacher', 'albertan', 'lgbtqalli', 'he', 'him', 'mastod ...

# %%
len(tokens)
# Out:
# 113265

# %%
len(stemmed_words)
# Out:
# 113265

# %%
# Download WordNet for Lemmatizer
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/obianujuanuma/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Create lemmatizer instance
lemmatizer = WordNetLemmatizer()
# Apply lemmatization, handling hyphenation
def lemmatize_word(word):
    if '-' in word:
        return '-'.join([lemmatizer.lemmatize(part) for part in word.split('-')])
    else:
        return lemmatizer.lemmatize(word)
    
lemmatized_tokens = [lemmatize_word(token) for token in tokens]
print(f'Lemmatized tokens {lemmatized_tokens}')
# Out:
# Lemmatized tokens ['watch', 'or', 'listen', 'live', 'weekday', 'at', 'mt', 'at', 'ryanjespersen', 'com', 'subscribe', 'via', 'youtube', 'or', 'your', 'favourite', 'podcast', 'app', 'realtalkrj', 'watch', 'or', 'listen', 'live', 'weekday', 'at', 'mt', 'at', 'ryanjespersen', 'com', 'subscribe', 'via', 'youtube', 'or', 'your', 'favourite', 'podcast', 'app', 'realtalkrj', 'chubby', 'and', 'hot', 'always', 'stir', 'the', 'pot', 'chubby', 'and', 'hot', 'always', 'stir', 'the', 'pot', 'journalist', 'publisher', 'of', 'rebel', 'news', 'telling', 'the', 'other', 'side', 'of', 'the', 'story', 'awarded', 'the', 'queen', 'diamond', 'jubilee', 'medal', 'for', 'advancing', 'freedom', 'of', 'expression', 'edmonton', 'city', 'councillor', 'for', 'yeg', 'urban', 'planner', 'sustainability', 'sociologist', 'founder', 'city', 'climate', 'action', 'health', 'inclusion', 'she', 'her', 'yegcc', 'albertan', 'mom', 'to', 'child', 'dog', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', 'albertan', 'mom', 'to', 'child', 'dog', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', 'albertan', 'mom', 'to', 'child', 'dog', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', 'albertan', 'mom', 'to', 'child', 'dog', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', 'former', 'progressive', 'conservative', 'specializing', 'in', 'delivering', 'satirical', 'irony', 'through', 'interpretive', 'dance', 'since', 'june', 'if', 'anyone', 'order', 'merlot', "i'm", 'leaving', 'former', 'progressive', 'conservative', 'specializing', 'in', 'delivering', 'satirical', 'irony', 'through', 'interpretive', 'dance', 'since', 'june', 'if', 'anyone', 'order', 'merlot', "i'm", 'leaving', "i'm", 'kuno', "gov't", 'qualified', 'service', 'dog', 'in', 'alberta', 'canada', 'my', 'job', 'is', 'taking', 'care', 'of', 'my', 'person', 'bilateral', 'amputee', 'weatherdog', 'spokesdog', 'for', 'the', 'disabled', "i'm", 'kuno', "gov't", 'qualified', 'service', 'dog', 'in', 'alberta', 'canada', 'my', 'job', 'is', 'taking', 'care', 'of', 'my', 'person', 'bilateral', 'amputee', 'weatherdog', 'spokesdog', 'for', 'the', 'disabled', 'albertan', 'mom', 'to', 'child', 'dog', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', 'albertan', 'mom', 'to', 'child', 'dog', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', 'albertan', 'mom', 'to', 'child', 'dog', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', 'albertan', 'mom', 'to', 'child', 'dog', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', 'albertan', 'mom', 'to', 'child', 'dog', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', 'albertan', 'mom', 'to', 'child', 'dog', 'wife', 'friend', 'leader', 'of', 'the', 'alberta', 'ndp', 'account', 'run', 'by', 'rachel', 'notley', 'and', 'staff', 'she', 'her', 'ableg', "i'm", 'kuno', "gov't", 'qualified', 'service', 'dog', 'in', 'alberta', 'canada', 'my', 'job', 'is', 'taking', 'care', 'of', 'my', 'person', 'bilateral', 'amputee', 'weatherdog', 'spokesdog', 'for', 'the', 'disabled', 'think-tank', 'president', 'out-of-touch', 'opinion', 'elite', 'proud', 'husband', 'of', 'teacher', 'albertan', 'lgbtqally', 'he', 'him', 'mastodon', 'seandunn', 'hachyderm', 'io', 'think-tank', 'president', 'out-of-touc ...

# %%
len(lemmatized_tokens)
# Out:
# 113265

# %%
# Top 10 words after stemming
top_ten_stems = Counter(stemmed_words).most_common(10)
top_ten_stems
# Out:
# [('and', 3520),
#  ('the', 2868),
#  ('of', 2232),
#  ('to', 2182),
#  ('in', 1553),
#  ('for', 1511),
#  ('alberta', 1052),
#  ('is', 922),
#  ('my', 899),
#  ('on', 829)]

# %%
# Top 10 words after lemmatization
top_ten_lemmas = Counter(lemmatized_tokens).most_common(10)
top_ten_lemmas
# Out:
# [('and', 3520),
#  ('the', 2868),
#  ('of', 2232),
#  ('to', 2182),
#  ('in', 1553),
#  ('for', 1511),
#  ('alberta', 1052),
#  ('is', 922),
#  ('my', 899),
#  ('on', 829)]

# %%
# Stemmed words vs Lemmas
top_ten_stems == top_ten_lemmas
# Out:
# True

# %% [markdown]
# Since both stemming and lemmatization give the same top 10 numbers, the analysis does not benefit from the complexities of lemmatization. So, it in this case, it is better to go with stemming.

# %% [markdown]
# #### Reference:
# ##### First prompt on Deepseek: libraries to use for porter and ntlk lemmatizer in Python
# ##### Last prompt on Deepseek: The top ten words without for both stemming and lemmatization are the same
#
# Lcit-Aisc-T3-S. (n.d.). Group2/NLP/Shahnaz/Case_Study_1_Shahnaz_Palakunnil_Moosa.ipynb at dev · LCIT-AISC-T3-S25/Group2. GitHub. https://github.com/LCIT-AISC-T3-S25/Group2/blob/dev/NLP/Shahnaz/Case_Study_1_Shahnaz_Palakunnil_Moosa.ipynb
